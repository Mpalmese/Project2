# %% [markdown]
# ## Flask

# %%
import pandas as pd
from sqlalchemy import create_engine
import MySQLdb

# %%
lifecsv = pd.read_csv("Life Expectancy (years) by Country.csv", encoding='latin1')
lifecsv.head()
# Out:
#                                Series Name     Series Code    Country Name  \
# 0  Life expectancy at birth, total (years)  SP.DYN.LE00.IN     Afghanistan
# 1  Life expectancy at birth, total (years)  SP.DYN.LE00.IN         Albania
# 2  Life expectancy at birth, total (years)  SP.DYN.LE00.IN         Algeria
# 3  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  American Samoa
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN         Andorra
#
#   Country Code 1999 [YR1999] 2000 [YR2000] 2001 [YR2001] 2002 [YR2002]  \
# 0          AFG        54.959        55.482        56.044        56.637
# 1          ALB        73.588        73.955        74.286        74.575
# 2          DZA        69.822        70.292        70.778        71.276
# 3          ASM            ..            ..            ..            ..
# 4          AND            ..            ..            ..            ..
#
#   2003 [YR2003] 2004 [YR2004]      ...      2008 [YR2008] 2009 [YR2009]  \
# 0         57.25        57.875      ...             60.243        60.754
# 1         74.82        75.028      ...             75.943        76.281
# 2         71.78        72.281      ...             74.032        74.374
# 3            ..            ..      ...                 ..            ..
# 4            ..            ..      ...                 ..            ..
#
#   2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 0        61.226        61.666        62.086        62.494        62.895
# 1        76.652        77.031        77.389        77.702        77.963
# 2        74.676        74.944        75.187        75.418        75.641
# 3            ..            ..            ..            ..            ..
# 4            ..            ..            ..            ..            ..
#
#   2015 [YR2015] 2016 [YR2016] 2017 [YR2017]
# 0        63.288        63.673        64.047
# 1        78.174        78.345        78.495
# 2         75.86        76.078        76.293
# 3            ..            ..            ..
# 4            ..            ..            ..
#
# [5 rows x 23 columns]

# %%
lifecsv = lifecsv.drop(columns=['Series Name','Series Code'])
lifecsv.head()
# Out:
#      Country Name Country Code 1999 [YR1999] 2000 [YR2000] 2001 [YR2001]  \
# 0     Afghanistan          AFG        54.959        55.482        56.044
# 1         Albania          ALB        73.588        73.955        74.286
# 2         Algeria          DZA        69.822        70.292        70.778
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   2002 [YR2002] 2003 [YR2003] 2004 [YR2004] 2005 [YR2005] 2006 [YR2006]  \
# 0        56.637         57.25        57.875          58.5         59.11
# 1        74.575         74.82        75.028        75.217        75.418
# 2        71.276         71.78        72.281        72.767        73.225
# 3            ..            ..            ..            ..            ..
# 4            ..            ..            ..            ..            ..
#
#        ...      2008 [YR2008] 2009 [YR2009] 2010 [YR2010] 2011 [YR2011]  \
# 0      ...             60.243        60.754        61.226        61.666
# 1      ...             75.943        76.281        76.652        77.031
# 2      ...             74.032        74.374        74.676        74.944
# 3      ...                 ..            ..            ..            ..
# 4      ...                 ..            ..            ..            ..
#
#   2012 [YR2012] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]  \
# 0        62.086        62.494        62.895        63.288        63.673
# 1        77.389        77.702        77.963        78.174        78.345
# 2        75.187        75.418        75.641         75.86        76.078
# 3            ..            ..            ..            ..            ..
# 4            ..            ..            ..            ..            ..
#
#   2017 [YR2017]
# 0        64.047
# 1        78.495
# 2        76.293
# 3            ..
# 4            ..
#
# [5 rows x 21 columns]

# %%
lifecsv = lifecsv.rename(columns={'1999 [YR1999]':'1999','2000 [YR2000]':'2000','2001 [YR2001]':'2001','2002 [YR2002]':'2002','2003 [YR2003]':'2003','2004 [YR2004]':'2004','2005 [YR2005]':'2005','2006 [YR2006]':'2006','2007 [YR2007]':'2007','2008 [YR2008]':'2008','2009 [YR2009]':'2009','2010 [YR2010]':'2010','2011 [YR2011]':'2011','2012 [YR2012]':'2012','2013 [YR2013]':'2013','2014 [YR2014]':'2014','2015 [YR2015]':'2015','2016 [YR2016]':'2016','2017 [YR2017]':'2017'})
lifecsv.head()
# Out:
#      Country Name Country Code    1999    2000    2001    2002   2003    2004  \
# 0     Afghanistan          AFG  54.959  55.482  56.044  56.637  57.25  57.875
# 1         Albania          ALB  73.588  73.955  74.286  74.575  74.82  75.028
# 2         Algeria          DZA  69.822  70.292  70.778  71.276  71.78  72.281
# 3  American Samoa          ASM      ..      ..      ..      ..     ..      ..
# 4         Andorra          AND      ..      ..      ..      ..     ..      ..
#
#      2005    2006   ...      2008    2009    2010    2011    2012    2013  \
# 0    58.5   59.11   ...    60.243  60.754  61.226  61.666  62.086  62.494
# 1  75.217  75.418   ...    75.943  76.281  76.652  77.031  77.389  77.702
# 2  72.767  73.225   ...    74.032  74.374  74.676  74.944  75.187  75.418
# 3      ..      ..   ...        ..      ..      ..      ..      ..      ..
# 4      ..      ..   ...        ..      ..      ..      ..      ..      ..
#
#      2014    2015    2016    2017
# 0  62.895  63.288  63.673  64.047
# 1  77.963  78.174  78.345  78.495
# 2  75.641   75.86  76.078  76.293
# 3      ..      ..      ..      ..
# 4      ..      ..      ..      ..
#
# [5 rows x 21 columns]

# %%
# Create database connection
rds_connection_string = "root:Password1@localhost/life_expectancy_db"
engine = create_engine(f'mysql://{rds_connection_string}')
conn = engine.connect()

# %%
# Confirm tables
engine.table_names()
# Out:
# ['life_expectancy_db']

# %%
# Load data into Database
lifecsv.to_sql(name='life_expectancy_db', con=engine, if_exists='replace', index=False)

# %%
# Query All Records in the the Database
data = pd.read_sql("SELECT * FROM life_expectancy_db", conn)
data.head()
# Out:
#      Country Name Country Code    1999    2000    2001    2002   2003    2004  \
# 0     Afghanistan          AFG  54.959  55.482  56.044  56.637  57.25  57.875
# 1         Albania          ALB  73.588  73.955  74.286  74.575  74.82  75.028
# 2         Algeria          DZA  69.822  70.292  70.778  71.276  71.78  72.281
# 3  American Samoa          ASM      ..      ..      ..      ..     ..      ..
# 4         Andorra          AND      ..      ..      ..      ..     ..      ..
#
#      2005    2006   ...      2008    2009    2010    2011    2012    2013  \
# 0    58.5   59.11   ...    60.243  60.754  61.226  61.666  62.086  62.494
# 1  75.217  75.418   ...    75.943  76.281  76.652  77.031  77.389  77.702
# 2  72.767  73.225   ...    74.032  74.374  74.676  74.944  75.187  75.418
# 3      ..      ..   ...        ..      ..      ..      ..      ..      ..
# 4      ..      ..   ...        ..      ..      ..      ..      ..      ..
#
#      2014    2015    2016    2017
# 0  62.895  63.288  63.673  64.047
# 1  77.963  78.174  78.345  78.495
# 2  75.641   75.86  76.078  76.293
# 3      ..      ..      ..      ..
# 4      ..      ..      ..      ..
#
# [5 rows x 21 columns]

# %%
# route for map page (color coded countries with layers based on 2017 life expectancy or income level)

# %%
# route for plotly line (search by country - shows life expectancy over time)

# %%
# route for plotly pie (income level of the world)
